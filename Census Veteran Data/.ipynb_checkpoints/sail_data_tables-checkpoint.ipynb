# %% [markdown]
# # Test Visualizations

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt

# %%
sail = pd.read_csv('sail_by_year.csv')

# %%
# for easy viewing
sail_mental_health = sail.iloc[13:17]

benchmark_columns = [0] + list(range(3, 82, 5))
sandiego_columns = [0] + list(range(2, 82,5))
tenp_columns = [0] + list(range(4, 82, 5))
fiftyp_columns = [0] + list(range(5, 82, 5))
ninetyp_columns = [0] + list(range(6, 82, 5))

mental_health_benchmark = sail_mental_health.iloc[:, benchmark_columns]
mental_health_sandiego = sail_mental_health.iloc[:, sandiego_columns]
mental_health_tenp = sail_mental_health.iloc[:, tenp_columns]
mental_health_fiftyp = sail_mental_health.iloc[:, fiftyp_columns]
mental_health_ninetyp = sail_mental_health.iloc[:, ninetyp_columns]
sail_mental_health
# Out:
#                      Measure        Measure Unit  san_diego_q1_2015  \
# 13             Mental Health  Standardized score              0.291
# 14    1. Population coverage  Standardized score             -0.150
# 15     2. Continuity of care  Standardized score              0.524
# 16     3. Experience of care  Standardized score              0.197
#
#     benchmark_q1_2015  10th_q1_2015  50th_q1_2015  90th_q1_2015  \
# 13              1.130        -1.351        -0.094         1.130
# 14              1.147        -1.194         0.009         1.147
# 15              0.994        -1.167        -0.083         0.994
# 16              1.023        -1.153        -0.046         1.023
#
#     san_diego_q2_2015  benchmark_q2_2015  10th_q2_2015      ...       \
# 13              0.391              1.142        -1.376      ...
# 14             -0.069              1.115        -1.169      ...
# 15              0.640              0.947        -1.195      ...
# 16              0.197              1.023        -1.153      ...
#
#     san_diego_q3_2018  benchmark_q3_2018  10th_q3_2018  50th_q3_2018  \
# 13             -0.370              1.424        -0.747         0.326
# 14             -0.928              1.176        -1.075        -0.248
# 15              1.083              2.086        -0.263         0.855
# 16             -0.970              1.013        -1.073         0.066
#
#     90th_q3_2018  san_diego_q4_2018  benchmark_q4_2018  10th_q4_2018  \
# 13         1.424             -0.510              1.268        -1.124
# 14         1.176             -0.689              1.171        -1.127
# 15         2.086              0.357              0.965        -1.225
# 16         1.013             -0.768              1.445        -1.071
#
#     50th_q4_2018  90th_q4_2018
# 13        -0.176         1.268
# 14        -0.217         1.171
# 15        -0.111         0.965
# 16        -0.049         1.445
#
# [4 rows x 82 columns]

# %%
# san diego mental health
mental_health_sandiego_data = {"mental_health": list(mental_health_sandiego.iloc[0])[1:],\
                          "population_coverage": list(mental_health_sandiego.iloc[1])[1:],\
                          "continuity_of_care": list(mental_health_sandiego.iloc[2])[1:],\
                          "experience_of_care": list(mental_health_sandiego.iloc[3])[1:]}
mental_health_sandiego2 = pd.DataFrame(data = mental_health_sandiego_data)

# benchmark mental health
mental_health_benchmark_data = {"mental_health": list(mental_health_benchmark.iloc[0])[1:],\
                          "population_coverage": list(mental_health_benchmark.iloc[1])[1:],\
                          "continuity_of_care": list(mental_health_benchmark.iloc[2])[1:],\
                          "experience_of_care": list(mental_health_benchmark.iloc[3])[1:]}
mental_health_benchmark2 = pd.DataFrame(data = mental_health_benchmark_data)

# 10th percentile mental health
mental_health_tenp_data = {"mental_health": list(mental_health_tenp.iloc[0])[1:],\
                          "population_coverage": list(mental_health_tenp.iloc[1])[1:],\
                          "continuity_of_care": list(mental_health_tenp.iloc[2])[1:],\
                          "experience_of_care": list(mental_health_tenp.iloc[3])[1:]}
mental_health_tenp2 = pd.DataFrame(data = mental_health_tenp_data)

# 50th percentile mental health
mental_health_fiftyp_data = {"mental_health": list(mental_health_fiftyp.iloc[0])[1:],\
                          "population_coverage": list(mental_health_fiftyp.iloc[1])[1:],\
                          "continuity_of_care": list(mental_health_fiftyp.iloc[2])[1:],\
                          "experience_of_care": list(mental_health_fiftyp.iloc[3])[1:]}
mental_health_fiftyp2 = pd.DataFrame(data = mental_health_fiftyp_data)

# 90th percentile mental health
mental_health_ninetyp_data = {"mental_health": list(mental_health_ninetyp.iloc[0])[1:],\
                          "population_coverage": list(mental_health_ninetyp.iloc[1])[1:],\
                          "continuity_of_care": list(mental_health_ninetyp.iloc[2])[1:],\
                          "experience_of_care": list(mental_health_ninetyp.iloc[3])[1:]}
mental_health_ninetyp2 = pd.DataFrame(data = mental_health_ninetyp_data)

# %%
pd.DataFrame({"mental_health_sandiego": list(mental_health_sandiego.iloc[0])[1:],\
                "mental_health_benchmark": list(mental_health_benchmark.iloc[0])[1:],\
                "mental_health_10thp": list(mental_health_tenp.iloc[0])[1:],\
                "mental_health_50thp": list(mental_health_fiftyp.iloc[0])[1:],\
                "mental_health_90thp": list(mental_health_ninetyp.iloc[0])[1:]}).plot()

# %%
pd.DataFrame({"population_coverage_sandiego": list(mental_health_sandiego.iloc[1])[1:],\
                "population_coverage_benchmark": list(mental_health_benchmark.iloc[1])[1:],\
                "population_coverage_10thp": list(mental_health_tenp.iloc[1])[1:],\
                "population_coverage_50thp": list(mental_health_fiftyp.iloc[1])[1:],\
                "population_coverage_90thp": list(mental_health_ninetyp.iloc[1])[1:]}).plot()

# %%
pd.DataFrame({"continuity_sandiego": list(mental_health_sandiego.iloc[2])[1:],\
                "continuity_benchmark": list(mental_health_benchmark.iloc[2])[1:],\
                "continuity_10thp": list(mental_health_tenp.iloc[2])[1:],\
                "continuity_50thp": list(mental_health_fiftyp.iloc[2])[1:],\
                "continuity_90thp": list(mental_health_ninetyp.iloc[2])[1:]}).plot()

# %%
pd.DataFrame({"experience_sandiego": list(mental_health_sandiego.iloc[3])[1:],\
                "experience_benchmark": list(mental_health_benchmark.iloc[3])[1:],\
                "experience_10thp": list(mental_health_tenp.iloc[3])[1:],\
                "experience_50thp": list(mental_health_fiftyp.iloc[3])[1:],\
                "experience_90thp": list(mental_health_ninetyp.iloc[3])[1:]}).plot()

# %%
sail
# Out:
#                                               Measure        Measure Unit  \
# 0                                              Access                 NaN
# 1                           1. Primary care wait time                 NaN
# 2       a. New primary care appointments completed...                   %
# 3                            b. PCMH Access composite  casemix adjusted %
# 4         i. Get an urgent care appointment as soo...  casemix adjusted %
# 5         ii. Get a routine care appointment as so...  casemix adjusted %
# 6                         2. Specialty care wait time                 NaN
# 7       a. New specialty care appointments complet...                   %
# 8                          3. Mental health wait time                 NaN
# 9       a. New mental health appointments complete...                   %
# 10                             4. Call responsiveness                 NaN
# 11      a. Call center speed in responding to call...             seconds
# 12                    b. Call center abandonment rate                   %
# 13                                      Mental Health  Standardized score
# 14                             1. Population coverage  Standardized score
# 15                              2. Continuity of care  Standardized score
# 16                              3. Experience of care  Standardized score
# 17      a. PCMH timely appointment, care and infor...               wct %
# 18      b. Specialty Care timely appointment, care...               wct %
# 19       c. Days Waited for Urgent Appointment (PCMH)               wct %
#
#     san_diego_q1_2015  benchmark_q1_2015  10th_q1_2015  50th_q1_2015  \
# 0                 NaN                NaN           NaN           NaN
# 1                 NaN                NaN           NaN           NaN
# 2              90.367             99.740        83.536        97.367
# 3              38.434             53.800        32.078        42.025
# 4              41.454             59.919        30.553        45.549
# 5              51.982             66.284        41.417        54.364
# 6                 NaN                NaN           NaN           NaN
# 7              93.902             98.551        89.604        95.595
# 8                 NaN                NaN           NaN           NaN
# 9              98.120             99.885        96.667        99.196
# 10                NaN                NaN           NaN           NaN
# 11            153.625             19.052        19.052        58.461
# 12             16.260              3.359         3.359         8.918
# 13              0.291              1.130        -1.351        -0.094
# 14             -0.150              1.147        -1.194         0.009
# 15              0.524              0.994        -1.167        -0.083
# 16              0.197              1.023        -1.153        -0.046
# 17                NaN                NaN           NaN           NaN
# 18                NaN                NaN           NaN           NaN
# 19                NaN                NaN           NaN           NaN
#
#     90th_q1_2015  san_diego_q2_2015  benchmark_q2_2015  10th_q2_2015  \
# 0            NaN                NaN                NaN           NaN
# 1            NaN                NaN                NaN           NaN
# 2         99.740             93.991             99.745        84.923
# 3         53.800             50.556             52.372        32.065
# 4         59.919             47.357             56.676        33.595
# 5         66.284             56.953             64.422        42.470
# 6            NaN                NaN                NaN           NaN
# 7         98.551             94.608             98.437        89.128
# 8            NaN                NaN                NaN           NaN
# 9         99.885             97.692             99.854        95.918
# 10           NaN                NaN                NaN           NaN
# 11       195.731            232.438             21.377        21.377
# 12        22.063             22.231              3.760         3.760
# 13         1.130              0.391              1.142        -1.376
# 14         1.147             -0.069              1.115        -1.169
# 15         0.994              0.640              0.947        -1.195
# 16         1.023              0.197              1.023        -1.153
# 17           NaN                NaN                NaN           NaN
# 18           NaN                NaN                NaN           NaN
# 19           NaN                NaN                NaN           NaN
#
#         ...       san_diego_q3_2018  benchmark_q3_2018  10th_q3_2018  \
# 0       ...                     NaN                NaN           NaN
# 1       ...                     NaN                NaN           NaN
# 2       ...                  96.518             93.687        63.311
# 3       ...                     NaN                NaN           NaN
# 4       ...                     NaN                NaN           NaN
# 5       ...                     NaN                NaN           NaN
# 6       ...                     NaN                NaN           NaN
# 7       ...                  71.904             84.392        67.804
# 8       ...                     NaN                NaN           NaN
# 9       ...                  92.777             97.115        86.691
# 10      ...                     NaN                NaN           NaN
# 11      ...                  51.508             20.925        20.925
# 12      ...                   5.739              2.787         2.787
# 13      ...                  -0.370              1.424        -0.747
# 14      ...                  -0.928              1.176        -1.075
# 15      ...                   1.083              2.086        -0.263
# 16      ...                  -0.970              1.013        -1.073
# 17      ...                  53.659             61.127        43.484
# 18      ...                  47.118             59.433        42.703
# 19      ...                  26.254             50.440        29.348
#
#     50th_q3_2018  90th_q3_2018  san_diego_q4_2018  benchmark_q4_2018  \
# 0            NaN           NaN                NaN                NaN
# 1            NaN           NaN                NaN                NaN
# 2         80.444        93.687             96.616             93.214
# 3            NaN           NaN                NaN                NaN
# 4            NaN           NaN                NaN                NaN
# 5            NaN           NaN                NaN                NaN
# 6            NaN           NaN                NaN                NaN
# 7         75.419        84.392             71.274             84.043
# 8            NaN           NaN                NaN                NaN
# 9         92.311        97.115             92.839             96.897
# 10           NaN           NaN                NaN                NaN
# 11        50.698       108.351             45.704             20.957
# 12         6.704        12.203              5.264              2.625
# 13         0.326         1.424             -0.510              1.268
# 14        -0.248         1.176             -0.689              1.171
# 15         0.855         2.086              0.357              0.965
# 16         0.066         1.013             -0.768              1.445
# 17        53.032        61.127             54.677             62.245
# 18        50.830        59.433             49.288             59.918
# 19        40.916        50.440             29.406             50.771
#
#     10th_q4_2018  50th_q4_2018  90th_q4_2018
# 0            NaN           NaN           NaN
# 1            NaN           NaN           NaN
# 2         63.571        80.919        93.214
# 3            NaN           NaN           NaN
# 4            NaN           NaN           NaN
# 5            NaN           NaN           NaN
# 6            NaN           NaN           NaN
# 7         66.291        75.429        84.043
# 8            NaN           NaN           NaN
# 9         86.406        92.464        96.897
# 10           NaN           NaN           NaN
# 11        20.957        44.753       110.742
# 12         2.625         6.232        10.896
# 13        -1.124        -0.176         1.268
# 14        -1.127        -0.217         1.171
# 15        -1.225        -0.111         0.965
# 16        -1.071        -0.049         1.445
# 17        43.577        54.019        62.245
# 18        43.161        50.200        59.918
# 19        31.208        41.029        50.771
#
# [20 rows x 82 columns]
