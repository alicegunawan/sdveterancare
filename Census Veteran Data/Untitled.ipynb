# %% [markdown]
# # VA Performance Data

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
import bokeh.plotting as bk

# %%
va_ipshep = pd.read_csv('ipshep_oct2016.csv', encoding='latin1')

# %%
clean_room = va_ipshep.iloc[range(0, len(va_ipshep), 11)]
nurse_comm = va_ipshep.iloc[range(1, len(va_ipshep), 11)]
doc_comm = va_ipshep.iloc[range(2, len(va_ipshep), 11)]
hosp_respon = va_ipshep.iloc[range(3, len(va_ipshep), 11)]
pain_manage = va_ipshep.iloc[range(4, len(va_ipshep), 11)]
med_comm = va_ipshep.iloc[range(5, len(va_ipshep), 11)]
discharge_info = va_ipshep.iloc[range(6, len(va_ipshep), 11)]
care_transition = va_ipshep.iloc[range(7, len(va_ipshep), 11)]
overall_rating = va_ipshep.iloc[range(8, len(va_ipshep), 11)]
quiet = va_ipshep.iloc[range(9, len(va_ipshep), 11)]
will_recommend = va_ipshep.iloc[range(10, len(va_ipshep), 11)]

# %% [markdown]
# ## Individual Measures

# %%
test = bk.figure(plot_width=400, plot_height=400)
test.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=20, color="navy", alpha=0.5)

# %%
clean_room.reset_index().plot("AnswerPercent")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-79948c0c37d4> in <module>()
# ----> 1 clean_room.reset_index().plot("AnswerPercent").show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
va_ipshep
# Out:
#      ProviderID                                       HospitalName  \
# 0        20003F                            TOGUS VA MEDICAL CENTER
# 1        20003F                            TOGUS VA MEDICAL CENTER
# 2        20003F                            TOGUS VA MEDICAL CENTER
# 3        20003F                            TOGUS VA MEDICAL CENTER
# 4        20003F                            TOGUS VA MEDICAL CENTER
# 5        20003F                            TOGUS VA MEDICAL CENTER
# 6        20003F                            TOGUS VA MEDICAL CENTER
# 7        20003F                            TOGUS VA MEDICAL CENTER
# 8        20003F                            TOGUS VA MEDICAL CENTER
# 9        20003F                            TOGUS VA MEDICAL CENTER
# 10       20003F                            TOGUS VA MEDICAL CENTER
# 11       47001F                  WHITE RIVER JCT VA MEDICAL CENTER
# 12       47001F                  WHITE RIVER JCT VA MEDICAL CENTER
# ...
